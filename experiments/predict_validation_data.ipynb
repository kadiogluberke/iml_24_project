# %%
import pickle

import pandas as pd
import numpy as np

from sklearn import metrics, model_selection, ensemble

from tqdm import tqdm

# %%
df_validation = pd.read_csv("../data/datasets/validation_data.csv")
df_validation.head()
# Out:
#    landmark_0-axis_0  landmark_0-axis_1  landmark_0-axis_2  landmark_1-axis_0  \
# 0           0.583031           1.000000       9.627691e-07           0.943927
# 1           0.164910           0.976234       1.126536e-07           0.379390
# 2           0.050025           1.000000      -1.011456e-07           0.393686
# 3           0.228598           1.000000       9.513732e-07           0.558540
# 4           0.076063           0.934002       2.967901e-07           0.327852
#
#    landmark_1-axis_1  landmark_1-axis_2  landmark_2-axis_0  landmark_2-axis_1  \
# 0           0.849769          -0.038193           1.000000           0.637765
# 1           1.000000          -0.071483           0.627130           0.887643
# 2           0.965069          -0.056856           0.736160           0.866284
# 3           0.880594          -0.001125           0.763987           0.735810
# 4           1.000000          -0.122011           0.623386           0.917373
#
# ...

# %%
X_cols = [col for col in df_validation.columns if col != 'label']

# %%
X_validation = df_validation[X_cols]
y_validation = df_validation.label

# %%
with open('../models/random_forest_best/random_forest_best.pkl', 'rb') as file:
    clf = pickle.load(file)

# %%
validation_predictions = clf.predict(X_validation)

# %%
val_acc = metrics.accuracy_score(y_validation, validation_predictions)

# %%
val_acc
# Out:
# 0.9878304007441283
